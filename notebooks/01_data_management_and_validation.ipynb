# %% [markdown]
# # Microclimate Forecasting System (Full Software Pipeline)
#
# Runs full CSV-based workflow: preprocessing, coordinated forecasting, control simulation, and reporting.

# %%
from src.pipeline_data_prep import run_full_project_workflow
results = run_full_project_workflow()
results
